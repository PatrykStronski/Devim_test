# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./data/train.csv')

df_nan_bad = df.loc[df.bad.isna()]

df_nan_bad.head(10)
# Out:
#     order_id  cred_sum_cc_all  mfo_inqs_count_month  all_closed_creds_sum_all  \
# 0    5498546              0.0                     0                     40364
# 1    5498604           1500.0                     0                     23456
# 2    5498609              0.1                     0                     17999
# 3    5498645           5000.0                     0                    313247
# 4    5498647              0.0                     0                         0
# 5    5498726          31000.1                     0                      9800
# 6    5499267          29400.0                     0                     18000
# 7    5499337         158000.0                     6                    845853
# 11   5499444          48000.0                     6                     31611
# 13   5499565              0.0                     1                         0
#
#     bank_inqs_count_quarter  cred_max_overdue_max_ly  \
# 0                         0                     0.00
# ...

# %%
sns.distplot(df_nan_bad['cred_sum_cc_all'])
plt.title('cred_sum_cc_all')
plt.show()

# %%
sns.distplot(df_nan_bad['mfo_inqs_count_month'])
plt.title('mfo_inqs_count_month')
plt.show()

# %%
sns.distplot(df_nan_bad['all_closed_creds_sum_all'])
plt.title('all_closed_creds_sum_all')
plt.show()

# %%
sns.distplot(df_nan_bad['bank_inqs_count_quarter'])
plt.title('bank_inqs_count_quarter')
plt.show()

# %%
sns.distplot(df_nan_bad['cred_max_overdue_max_ly'])
plt.title('cred_max_overdue_max_ly')
plt.show()

# %%
sns.distplot(df_nan_bad['all_active_creds_sum_all'])
plt.title('all_active_creds_sum_all')
plt.show()

# %%
sns.distplot(df_nan_bad['mfo_last_days_all'])
plt.title('mfo_last_days_all')
plt.show()

# %%
sns.distplot(df_nan_bad['cred_sum_cc_ly'])
plt.title('cred_sum_cc_ly')
plt.show()

# %%
sns.distplot(df_nan_bad['cred_sum_debt_all_all'])
plt.title('cred_sum_debt_all_all')
plt.show()

# %%
sns.distplot(df_nan_bad['all_closed_creds_sum_ly'])
plt.title('all_closed_creds_sum_ly')
plt.show()

# %%
sns.distplot(df_nan_bad['mfo_cred_mean_sum_3lm'])
plt.title('mfo_cred_mean_sum_3lm')
plt.show()

# %%
sns.distplot(df_nan_bad['delay_more_sum_all'])
plt.title('delay_more_sum_all')
plt.show()

# %%
sns.distplot(df_nan_bad['all_creds_count_all'])
plt.title('all_creds_count_all')
plt.show()

# %%
sns.distplot(df_nan_bad['cred_day_overdue_all_sum_all'])
plt.title('cred_day_overdue_all_sum_all')
plt.show()

# %%
sns.distplot(df_nan_bad['cred_max_overdue_max_3lm'])
plt.title('cred_max_overdue_max_3lm')
plt.show()

# %%
sns.distplot(df_nan_bad['mfo_closed_count_ly'])
plt.title('mfo_closed_count_ly')
plt.show()

# %%
sns.distplot(df_nan_bad['cred_sum_overdue_cc_all'])
plt.title('cred_sum_overdue_cc_all')
plt.show()

# %%
sns.displot(df_nan_bad, x='count_overdue_all_3lm')
plt.title('count_overdue_all_3lm')
plt.show()

# %%
sns.distplot(df_nan_bad['all_creds_count_lm'])
plt.title('all_creds_count_lm')
plt.show()

# %%
sns.distplot(df_nan_bad['work_code'])
plt.title('work_code')
plt.show()

# %%
sns.distplot(df_nan_bad['month_income'])
plt.title('month_income')
plt.show()

# %%
sns.displot(df_nan_bad, x='region')
plt.title('region')
plt.show()
