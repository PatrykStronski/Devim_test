# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./data/train.csv')

df.head(10)
# Out:
#    order_id  cred_sum_cc_all  mfo_inqs_count_month  all_closed_creds_sum_all  \
# 0   5498546              0.0                     0                     40364
# 1   5498604           1500.0                     0                     23456
# 2   5498609              0.1                     0                     17999
# 3   5498645           5000.0                     0                    313247
# 4   5498647              0.0                     0                         0
# 5   5498726          31000.1                     0                      9800
# 6   5499267          29400.0                     0                     18000
# 7   5499337         158000.0                     6                    845853
# 8   5499365          50000.0                     2                     58500
# 9   5499397          44000.0                     1                    367842
#
#    bank_inqs_count_quarter  cred_max_overdue_max_ly  all_active_creds_sum_all  \
# ...

# %%
sns.distplot(df['cred_sum_cc_all'])
plt.show()

# %%
sns.distplot(df['mfo_inqs_count_month'])
plt.show()

# %%
sns.distplot(df['all_closed_creds_sum_all'])
plt.show()

# %%
sns.distplot(df['bank_inqs_count_quarter'])
plt.show()

# %%
sns.distplot(df['cred_max_overdue_max_ly'])
plt.title('cred_max_overdue_max_ly')
plt.show()

# %%
sns.distplot(df['all_active_creds_sum_all'])
plt.title('all_active_creds_sum_all')
plt.show()

# %%
sns.distplot(df['mfo_last_days_all'])
plt.title('mfo_last_days_all')
plt.show()

# %%
sns.distplot(df['cred_sum_cc_ly'])
plt.title('cred_sum_cc_ly')
plt.show()

# %%
sns.distplot(df['cred_sum_debt_all_all'])
plt.title('cred_sum_debt_all_all')
plt.show()

# %%
sns.distplot(df['all_closed_creds_sum_ly'])
plt.title('all_closed_creds_sum_ly')
plt.show()

# %%
sns.distplot(df['mfo_cred_mean_sum_3lm'])
plt.title('mfo_cred_mean_sum_3lm')
plt.show()

# %%
sns.distplot(df['delay_more_sum_all'])
plt.title('delay_more_sum_all')
plt.show()

# %%
sns.distplot(df['all_creds_count_all'])
plt.title('all_creds_count_all')
plt.show()

# %%
sns.distplot(df['cred_day_overdue_all_sum_all'])
plt.title('cred_day_overdue_all_sum_all')
plt.show()

# %%
sns.distplot(df['cred_max_overdue_max_3lm'])
plt.title('cred_max_overdue_max_3lm')
plt.show()

# %%
sns.displot(df, x='mfo_closed_count_ly', stat='probability')
plt.title('mfo_closed_count_ly')
plt.show()

# %%
sns.distplot(df['cred_sum_overdue_cc_all'])
plt.title('cred_sum_overdue_cc_all')
plt.show()

# %%
sns.displot(df, x='count_overdue_all_3lm')
plt.title('count_overdue_all_3lm')
plt.show()

# %%
sns.displot(df, x='all_creds_count_lm')
plt.title('all_creds_count_lm')
plt.show()

# %%
sns.displot(df, x='work_code')
plt.title('work_code')
plt.show()

# %%
sns.distplot(df['month_income'])
plt.title('month_income')
plt.show()

# %%
sns.displot(df, x='region')
plt.title('region')
plt.show()
