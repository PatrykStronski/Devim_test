# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./data/train.csv')

df_nan_bad = df.loc[df.bad.isna()]


df_notnan_bad = df.drop(index=df_nan_bad.index)

df_notnan_bad.head(20)
# Out:
#     order_id  cred_sum_cc_all  mfo_inqs_count_month  all_closed_creds_sum_all  \
# 8    5499365          50000.0                     2                     58500
# 9    5499397          44000.0                     1                    367842
# 10   5499407              0.0                     1                     44500
# 12   5499448          81550.0                    11                    231604
# 17   5499715          45001.0                     0                    107584
# 18   5499796          35000.0                     2                     48437
# 27   5500052           3129.0                     1                     53700
# 31   5500284         114120.0                     0                    400884
# 35   5500368         764700.0                     0                   1320410
# 38   5500459          20000.0                     1                     31790
# 40   5500512          35000.0                     2                    131694
# 41   5500526              0.0                     1                     48600
# 42   5500551          25000.0                     1                     23000
# 44   5500592              0.0                     3                      7500
# 45   5500593              0.0                     5                     47899
# 47   5500678              0.0                     2                    167200
# 50   5500820          54000.0                     3                     79680
# 53   5500966           9000.0                     3                     20500
# 57   5501182         133000.0                     0                    482281
# 58   5501390           4000.0                     0                     26375
#
#     bank_inqs_count_quarter  cred_max_overdue_max_ly  \
# 8                        14                     0.00
# 9                         3                 24000.00
# 10                        0                     0.00
# 12                        5                     0.00
# 17                        0                  5975.24
# 18                        8                     0.00
# 27                        0                     0.00
# 31                        9                     0.00
# 35                        2                     0.00
# 38                       12                  5490.00
# 40                        1                  3616.35
# 41                        1                     0.00
# 42                       11                     0.00
# 44                        3                     0.00
# 45                       10                  2082.24
# 47                        1                     0.00
# 50                        8                     0.00
# 53                        5                     0.00
# 57                        7                 19000.00
# 58                        2                     0.00
#
#     all_active_creds_sum_all  mfo_last_days_all  cred_sum_cc_ly  \
# 8                      38000                 23         50000.0
# 9                      74695                  8             0.0
# 10                      5000                 29             0.0
# 12                    272086                 16             0.0
# 17                    267484               9999             1.0
# 18                         0                 48         35000.0
# 27                     66953                 14             0.0
# 31                     57200                  2             0.0
# 35                     99300                  7        200000.0
# 38                     28996                 25         20000.0
# 40                    378050                 23         35000.0
# 41                     36500                  5             0.0
# 42                    519500                 17             0.0
# 44                      8483                 15             0.0
# 45                     13770                 24             0.0
# 47                      2000                 27             0.0
# 50                    158000                  7             0.0
# 53                     36350                 12          9000.0
# 57                    144501                 41             0.0
# 58                     31195                409             0.0
#
#     cred_sum_debt_all_all  ...  cred_max_overdue_max_3lm  mfo_closed_count_ly  \
# 8                38000.00  ...                      0.00                    5
# 9                75295.00  ...                      0.00                   11
# 10                5000.00  ...                      0.00                    7
# 12              217493.70  ...                      0.00                    4
# 17              244351.87  ...                      0.00                    0
# 18                   0.00  ...                      0.00                    3
# 27               55164.40  ...                      0.00                    7
# 31               56992.00  ...                      0.00                   20
# 35               99300.00  ...                      0.00                    6
# 38               28996.00  ...                      0.00                    7
# 40              349598.27  ...                   3616.35                    5
# 41               36500.00  ...                      0.00                   11
# 42              514059.60  ...                      0.00                    3
# 44                8483.00  ...                      0.00                    3
# 45               13769.80  ...                      0.00                    5
# 47                2000.00  ...                      0.00                   21
# 50              130081.89  ...                      0.00                    7
# 53               36482.00  ...                      0.00                    5
# 57               77245.23  ...                  17760.00                   15
# 58               14448.36  ...                      0.00                    0
#
#     cred_sum_overdue_cc_all  count_overdue_all_3lm  all_creds_count_lm  \
# 8                      0.00                      0                   2
# 9                      0.00                      0                   3
# 10                     0.00                      0                   1
# 12                     0.00                      0                   4
# 17                     0.00                      0                   0
# 18                     0.00                      0                   0
# 27                     0.00                      0                   1
# 31                     0.00                      0                   3
# 35                     0.00                      0                   1
# 38                     0.00                      0                   3
# 40                     0.00                      1                   2
# 41                     0.00                      0                   7
# 42                     0.00                      0                   3
# 44                     0.00                      0                   2
# 45                     0.00                      0                   1
# 47                     0.00                      0                   1
# 50                     0.00                      0                   3
# 53                     0.00                      0                   6
# 57                115431.06                      2                   0
# 58                     0.00                      0                   0
#
#     work_code  month_income  region  bad  approved
# 8           1         35000       4  0.0         1
# 9           2         35000      61  1.0         1
# 10          4         50000      32  0.0         1
# 12          5         35000       1  1.0         1
# 17          5         35000      78  0.0         1
# 18          3         60000      39  0.0         1
# 27          3         20000      46  1.0         1
# 31          2         50000      71  0.0         1
# 35          1         50000      46  0.0         1
# 38          2         20000      53  0.0         1
# 40          4         35000      15  0.0         1
# 41          4         20000      80  1.0         1
# 42          5         35000      53  0.0         1
# 44          2         35000      65  0.0         1
# 45          3         35000      15  1.0         1
# 47          3         50000      87  0.0         1
# 50          2         50000      78  0.0         1
# 53          2         35000      29  0.0         1
# 57          4         35000      49  1.0         1
# 58          3         60000      19  0.0         1
#
# [20 rows x 25 columns]

# %%
sns.distplot(df_notnan_bad['cred_sum_cc_all'])
plt.show()

# %%
sns.displot(df_notnan_bad, x='mfo_inqs_count_month', stat='probability')
plt.show()

# %%
sns.distplot(df_notnan_bad['all_closed_creds_sum_all'])
plt.show()

# %%
sns.displot(df_notnan_bad, x='bank_inqs_count_quarter', stat='probability')
plt.show()

# %%
sns.distplot(df_notnan_bad['cred_max_overdue_max_ly'])
plt.title('cred_max_overdue_max_ly')
plt.show()

# %%
sns.distplot(df_notnan_bad['all_active_creds_sum_all'])
plt.title('all_active_creds_sum_all')
plt.show()

# %%
sns.distplot(df_notnan_bad['mfo_last_days_all'])
plt.title('mfo_last_days_all')
plt.show()

# %%
sns.distplot(df_notnan_bad['cred_sum_cc_ly'])
plt.title('cred_sum_cc_ly')
plt.show()

# %%
sns.distplot(df_notnan_bad['cred_sum_debt_all_all'])
plt.title('cred_sum_debt_all_all')
plt.show()

# %%
sns.distplot(df['all_closed_creds_sum_ly'])
plt.title('all_closed_creds_sum_ly')
plt.show()

# %%
sns.distplot(df_notnan_bad['mfo_cred_mean_sum_3lm'])
plt.title('mfo_cred_mean_sum_3lm')
plt.show()

# %%
sns.distplot(df_notnan_bad['delay_more_sum_all'])
plt.title('delay_more_sum_all')
plt.show()

# %%
sns.distplot(df_notnan_bad['all_creds_count_all'])
plt.title('all_creds_count_all')
plt.show()

# %%
sns.distplot(df_notnan_bad['cred_day_overdue_all_sum_all'])
plt.title('cred_day_overdue_all_sum_all')
plt.show()

# %%
sns.distplot(df_notnan_bad['cred_max_overdue_max_3lm'])
plt.title('cred_max_overdue_max_3lm')
plt.show()

# %%
sns.displot(df_notnan_bad, x='mfo_closed_count_ly', stat='probability')
plt.title('mfo_closed_count_ly')
plt.show()

# %%
sns.distplot(df_notnan_bad['cred_sum_overdue_cc_all'])
plt.title('cred_sum_overdue_cc_all')
plt.show()

# %%
sns.displot(df_notnan_bad, x='count_overdue_all_3lm')
plt.title('count_overdue_all_3lm')
plt.show()

# %%
sns.displot(df_notnan_bad, x='all_creds_count_lm')
plt.title('all_creds_count_lm')
plt.show()

# %%
sns.displot(df_notnan_bad, x='work_code')
plt.title('work_code')
plt.show()

# %%
sns.distplot(df_notnan_bad['month_income'])
plt.title('month_income')
plt.show()

# %%
sns.displot(df_notnan_bad, x='region')
plt.title('region')
plt.show()
